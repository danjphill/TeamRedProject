# %%
import torch
import pandas as pd
import numpy as np
from torch.nn import Linear
import torch.nn.functional as F
from sentence_transformers import SentenceTransformer
import json

import torch_geometric.transforms as T
from torch_geometric.nn import SAGEConv, to_hetero

from torch_geometric.data import HeteroData
from torch_geometric.transforms import ToUndirected, RandomLinkSplit

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %%
from neo4j import GraphDatabase, basic_auth

url= 'bolt://localhost:7687'
user = 'neo4j'
password = '12345678'

driver = GraphDatabase.driver(url, auth=(user, password))

def fetch_data(query, params={}):
  with driver.session() as session:
    result = session.run(query, params)
    return pd.DataFrame([r.values() for r in result], columns=result.keys())

# %%
fetch_data("""
CALL gds.graph.project('articles', ['Article', 'Colour'], 
  {IS_COLOUR: {orientation:'UNDIRECTED'}})
""")
# Out:
#                                       nodeProjection  \
# 0  {'Article': {'label': 'Article', 'properties':...
#
#                               relationshipProjection graphName  nodeCount  \
# 0  {'IS_COLOUR': {'orientation': 'UNDIRECTED', 'a...  articles       7824
#
#    relationshipCount  projectMillis
# 0              15550            118

# %%
fetch_data("""
CALL gds.fastRP.write('articles', {writeProperty:'fastrp', embeddingDimension:56})
""")
# Out:
#    nodeCount  nodePropertiesWritten  preProcessingMillis  computeMillis  \
# 0       7824                   7824                    1             50
#
#    writeMillis                                      configuration
# 0          631  {'writeConcurrency': 4, 'nodeSelfInfluence': 0...

# %%
def load_node(cypher, index_col, encoders=None, **kwargs):
    # Execute the cypher query and retrieve data from Neo4j
    df = fetch_data(cypher)
    df.set_index(index_col, inplace=True)
    # Define node mapping
    mapping = {index: i for i, index in enumerate(df.index.unique())}
    # Define node features
    x = None
    if encoders is not None:
        xs = [encoder(df[col]) for col, encoder in encoders.items()]
        x = torch.cat(xs, dim=-1)

    return x, mapping

# %%
def load_edge(cypher, src_index_col, src_mapping, dst_index_col, dst_mapping,
                  encoders=None, **kwargs):
    # Execute the cypher query and retrieve data from Neo4j
    df = fetch_data(cypher)
    # Define edge index
    src = [src_mapping[index] for index in df[src_index_col]]
    dst = [dst_mapping[index] for index in df[dst_index_col]]
    edge_index = torch.tensor([src, dst])
    # Define edge features
    edge_attr = None
    if encoders is not None:
        edge_attrs = [encoder(df[col]) for col, encoder in encoders.items()]
        edge_attr = torch.cat(edge_attrs, dim=-1)

    return edge_index, edge_attr

# %%
class SequenceEncoder(object):

    def __init__(self, model_name='all-MiniLM-L6-v2', device=None):
        self.device = device
        self.model = SentenceTransformer(model_name, device=device)

    @torch.no_grad()
    def __call__(self, df):
        x = self.model.encode(df.values, show_progress_bar=True,
                              convert_to_tensor=True, device=self.device)
        return x.cpu()

# %%
class GenresEncoder(object):

    def __init__(self, sep='|'):
        self.sep = sep

    def __call__(self, df):
        genres = set(g for col in df.values for g in col.split(self.sep))
        mapping = {genre: i for i, genre in enumerate(genres)}

        x = torch.zeros(len(df), len(mapping))
        for i, col in enumerate(df.values):
            for genre in col.split(self.sep):
                x[i, mapping[genre]] = 1
        return x

# %%
class IdentityEncoder(object):

    def __init__(self, dtype=None, is_list=False):
        self.dtype = dtype
        self.is_list = is_list

    def __call__(self, df):
        if self.is_list:
            return torch.stack([torch.tensor(el) for el in df.values])
        return torch.from_numpy(df.values).to(self.dtype)

# %%
customer_query = """
MATCH (c:Customer) RETURN c.customer_id AS customerId
"""

customer_x, customer_mapping = load_node(customer_query, index_col='customerId')

# %%
article_query = """
MATCH (a:Article)-[:IN_SECTION]->(section:Section)
WITH a, collect(section.sectionName) AS section_list
RETURN a.article_id AS article_id, a.articleName AS articleName, apoc.text.join(section_list, '|') AS sections, a.fastrp AS fastrp
"""

article_x, article_mapping = load_node(
    article_query, 
    index_col='article_id', encoders={
        'articleName': SequenceEncoder(),
        'sections': GenresEncoder(),
        'fastrp': IdentityEncoder(is_list=True)
    })
# Out:
# Batches:   0%|          | 0/243 [00:00<?, ?it/s]

# %%
count_query = """
MATCH (c:Customer)-[b:BOUGHT]->(a:Article) 
RETURN c.customer_id AS customerId, a.article_id AS articleId, b.count AS bCount
"""

edge_index, edge_label = load_edge(
    count_query,
    src_index_col='customerId',
    src_mapping=customer_mapping,
    dst_index_col='articleId',
    dst_mapping=article_mapping,
    encoders={'bCount': IdentityEncoder(dtype=torch.long)},
)

# %%
data = HeteroData()
data['customer'].x = torch.eye(len(customer_mapping), device=device)
data['article'].x = article_x
data['customer', 'bought', 'article'].edge_index = edge_index
data['customer', 'bought', 'article'].edge_label = edge_label
data.to(device, non_blocking=True)

print(edge_label)
# Out:
# tensor([1, 1, 1,  ..., 1, 1, 1])

# %%
data = ToUndirected()(data)
del data['article', 'rev_bought', 'customer'].edge_label  # Remove "reverse" label.

# 2. Perform a link-level split into training, validation, and test edges.
transform = RandomLinkSplit(
    num_val=0.1,
    num_test=0.1,
    neg_sampling_ratio=0.0,
    edge_types=[('customer', 'bought', 'article')],
    rev_edge_types=[('article', 'rev_bought', 'customer')],
)
train_data, val_data, test_data = transform(data)
print(train_data)
print(train_data['customer', 'article'])
# Out:
# HeteroData(
#   customer={ x=[9867, 9867] },
#   article={ x=[7775, 494] },
#   (customer, bought, article)={
#     edge_index=[2, 8000],
#     edge_label=[8000],
#     edge_label_index=[2, 8000]
#   },
#   (article, rev_bought, customer)={ edge_index=[2, 8000] }
# )
# {'edge_index': tensor([[2931, 2585, 2449,  ..., 3020, 9426, 9559],
#         [7432, 3634, 4517,  ..., 7071,  915, 7088]]), 'edge_label': tensor([1, 1, 1,  ..., 1, 1, 1]), 'edge_label_index': tensor([[2931, 2585, 2449,  ..., 3020, 9426, 9559],
#         [7432, 3634, 4517,  ..., 7071,  915, 7088]])}

# %%
class GNNEncoder(torch.nn.Module):
    def __init__(self, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = SAGEConv((-1, -1), hidden_channels)
        self.conv2 = SAGEConv((-1, -1), out_channels)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index).relu()
        x = self.conv2(x, edge_index)
        return x


class EdgeDecoder(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        self.lin1 = Linear(2 * hidden_channels, hidden_channels)
        self.lin2 = Linear(hidden_channels, 1)

    def forward(self, z_dict, edge_label_index):
        row, col = edge_label_index
        z = torch.cat([z_dict['customer'][row], z_dict['article'][col]], dim=-1)

        z = self.lin1(z).relu()
        z = self.lin2(z)
        return z.view(-1)

class Model(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        self.encoder = GNNEncoder(hidden_channels, hidden_channels)
        self.encoder = to_hetero(self.encoder, data.metadata(), aggr='sum')
        self.decoder = EdgeDecoder(hidden_channels)

    def forward(self, x_dict, edge_index_dict, edge_label_index):
        z_dict = self.encoder(x_dict, edge_index_dict)
        return self.decoder(z_dict, edge_label_index)

# %%
print(train_data['customer', 'article'].edge_label)
weight = torch.bincount(train_data['customer', 'article'].edge_label)
weight = weight.max() / weight

def weighted_mse_loss(pred, target, weight=None):
    weight = 1. if weight is None else weight[target].to(pred.dtype)
    return (weight * (pred - target.to(pred.dtype)).pow(2)).mean()
# Out:
# tensor([1, 1, 1,  ..., 1, 1, 1])

# %%
model = Model(hidden_channels=64).to(device)

# %%
# Due to lazy initialization, we need to run one model step so the number
# of parameters can be inferred:
with torch.no_grad():
    model.encoder(train_data.x_dict, train_data.edge_index_dict)

optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
def train():
    model.train()
    optimizer.zero_grad()
    pred = model(train_data.x_dict, train_data.edge_index_dict,
                 train_data['customer', 'bought', 'article'].edge_label_index)
    target = train_data['customer', 'bought', 'article'].edge_label
    loss = weighted_mse_loss(pred, target, weight)
    loss.backward()
    optimizer.step()
    return float(loss)

# %%
torch.no_grad()
def test(data):
    model.eval()
    pred = model(data.x_dict, data.edge_index_dict,
                 data['customer', 'bought', 'article'].edge_label_index)
    pred = pred.clamp(min=0, max=5)
    target = data['customer', 'bought', 'article'].edge_label.float()
    rmse = F.mse_loss(pred, target).sqrt()
    return float(rmse)

# %%
for epoch in range(1, 300):
    loss = train()
    train_rmse = test(train_data)
    val_rmse = test(val_data)
    test_rmse = test(test_data)
    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Train: {train_rmse:.4f}, '
          f'Val: {val_rmse:.4f}, Test: {test_rmse:.4f}')
# Out:
# Epoch: 001, Loss: 0.9623, Train: 0.5815, Val: 0.6836, Test: 0.6791
# Epoch: 002, Loss: 0.3381, Train: 0.7375, Val: 0.2444, Test: 0.2441
# Epoch: 003, Loss: 0.5440, Train: 0.1685, Val: 0.4378, Test: 0.4283
# Epoch: 004, Loss: 0.0284, Train: 0.4527, Val: 0.5599, Test: 0.5562
# Epoch: 005, Loss: 0.2049, Train: 0.4954, Val: 0.5694, Test: 0.5667
# Epoch: 006, Loss: 0.2454, Train: 0.4290, Val: 0.5203, Test: 0.5172
# Epoch: 007, Loss: 0.1841, Train: 0.2893, Val: 0.4279, Test: 0.4235
# Epoch: 008, Loss: 0.0837, Train: 0.1026, Val: 0.2971, Test: 0.2909
# Epoch: 009, Loss: 0.0105, Train: 0.2317, Val: 0.1643, Test: 0.1596
# Epoch: 010, Loss: 0.0537, Train: 0.3342, Val: 0.1223, Test: 0.1225
# Epoch: 011, Loss: 0.1117, Train: 0.2189, Val: 0.1381, Test: 0.1336
# Epoch: 012, Loss: 0.0479, Train: 0.0544, Val: 0.2046, Test: 0.1985
# Epoch: 013, Loss: 0.0030, Train: 0.1206, Val: 0.2705, Test: 0.2654
# Epoch: 014, Loss: 0.0145, Train: 0.1937, Val: 0.3070, Test: 0.3027
# Epoch: 015, Loss: 0.0375, Train: 0.2146, Val: 0.3124, Test: 0.3085
# Epoch: 016, Loss: 0.0461, Train: 0.1939, Val: 0.2909, Test: 0.2867
# Epoch: 017, Loss: 0.0376, Train: 0.1425, Val: 0.2474, Test: 0.2427
# Epoch: 018, Loss: 0.0203, Train: 0.0850, Val: 0.1902, Test: 0.1849
# Epoch: 019, Loss: 0.0072, Train: 0.0932, Val: 0.1336, Test: 0.1285
# Epoch: 020, Loss: 0.0087, Train: 0.1423, Val: 0.0965, Test: 0.0933
# Epoch: 021, Loss: 0.0203, Train: 0.1552, Val: 0.0818, Test: 0.0800
# Epoch: 022, Loss: 0.0241, Train: 0.1197, Val: 0.0809, Test: 0.0779
# Epoch: 023, Loss: 0.0143, Train: 0.0582, Val: 0.0985, Test: 0.0942
# Epoch: 024, Loss: 0.0034, Train: 0.0212, Val: 0.1273, Test: 0.1232
# Epoch: 025, Loss: 0.0004, Train: 0.0613, Val: 0.1526, Test: 0.1492
# Epoch: 026, Loss: 0.0038, Train: 0.0885, Val: 0.1665, Test: 0.1636
# Epoch: 027, Loss: 0.0078, Train: 0.0959, Val: 0.1668, Test: 0.1641
# Epoch: 028, Loss: 0.0092, Train: 0.0861, Val: 0.1542, Test: 0.1516
# Epoch: 029, Loss: 0.0074, Train: 0.0651, Val: 0.1315, Test: 0.1291
# Epoch: 030, Loss: 0.0042, Train: 0.0459, Val: 0.1034, Test: 0.1010
# Epoch: 031, Loss: 0.0021, Train: 0.0491, Val: 0.0760, Test: 0.0737
# Epoch: 032, Loss: 0.0024, Train: 0.0663, Val: 0.0557, Test: 0.0538
# Epoch: 033, Loss: 0.0044, Train: 0.0759, Val: 0.0457, Test: 0.0443
# Epoch: 034, Loss: 0.0058, Train: 0.0708, Val: 0.0442, Test: 0.0428
# Epoch: 035, Loss: 0.0050, Train: 0.0533, Val: 0.0503, Test: 0.0484
# Epoch: 036, Loss: 0.0028, Train: 0.0323, Val: 0.0632, Test: 0.0611
# Epoch: 037, Loss: 0.0010, Train: 0.0255, Val: 0.0785, Test: 0.0763
# Epoch: 038, Loss: 0.0006, Train: 0.0362, Val: 0.0911, Test: 0.0890
# Epoch: 039, Loss: 0.0013, Train: 0.0452, Val: 0.0976, Test: 0.0956
# Epoch: 040, Loss: 0.0020, Train: 0.0458, Val: 0.0968, Test: 0.0947
# Epoch: 041, Loss: 0.0021, Train: 0.0376, Val: 0.0889, Test: 0.0868
# Epoch: 042, Loss: 0.0014, Train: 0.0226, Val: 0.0757, Test: 0.0736
# Epoch: 043, Loss: 0.0005, Train: 0.0063, Val: 0.0602, Test: 0.0581
# Epoch: 044, Loss: 0.0000, Train: 0.0162, Val: 0.0461, Test: 0.0441
# Epoch: 045, Loss: 0.0003, Train: 0.0291, Val: 0.0365, Test: 0.0347
# Epoch: 046, Loss: 0.0008, Train: 0.0345, Val: 0.0325, Test: 0.0310
# Epoch: 047, Loss: 0.0012, Train: 0.0314, Val: 0.0336, Test: 0.0320
# Epoch: 048, Loss: 0.0010, Train: 0.0221, Val: 0.0391, Test: 0.0373
# Epoch: 049, Loss: 0.0005, Train: 0.0123, Val: 0.0478, Test: 0.0458
# Epoch: 050, Loss: 0.0002, Train: 0.0142, Val: 0.0570, Test: 0.0550
# Epoch: 051, Loss: 0.0002, Train: 0.0221, Val: 0.0641, Test: 0.0621
# Epoch: 052, Loss: 0.0005, Train: 0.0265, Val: 0.0671, Test: 0.0652
# Epoch: 053, Loss: 0.0007, Train: 0.0256, Val: 0.0656, Test: 0.0636
# Epoch: 054, Loss: 0.0007, Train: 0.0201, Val: 0.0600, Test: 0.0581
# Epoch: 055, Loss: 0.0004, Train: 0.0129, Val: 0.0519, Test: 0.0500
# Epoch: 056, Loss: 0.0002, Train: 0.0109, Val: 0.0434, Test: 0.0416
# Epoch: 057, Loss: 0.0001, Train: 0.0157, Val: 0.0365, Test: 0.0349
# Epoch: 058, Loss: 0.0002, Train: 0.0194, Val: 0.0326, Test: 0.0311
# Epoch: 059, Loss: 0.0004, Train: 0.0191, Val: 0.0319, Test: 0.0304
# Epoch: 060, Loss: 0.0004, Train: 0.0150, Val: 0.0342, Test: 0.0326
# Epoch: 061, Loss: 0.0002, Train: 0.0091, Val: 0.0386, Test: 0.0370
# Epoch: 062, Loss: 0.0001, Train: 0.0070, Val: 0.0438, Test: 0.0421
# Epoch: 063, Loss: 0.0000, Train: 0.0106, Val: 0.0482, Test: 0.0465
# Epoch: 064, Loss: 0.0001, Train: 0.0135, Val: 0.0505, Test: 0.0488
# Epoch: 065, Loss: 0.0002, Train: 0.0134, Val: 0.0501, Test: 0.0484
# Epoch: 066, Loss: 0.0002, Train: 0.0103, Val: 0.0473, Test: 0.0456
# Epoch: 067, Loss: 0.0001, Train: 0.0055, Val: 0.0428, Test: 0.0412
# Epoch: 068, Loss: 0.0000, Train: 0.0036, Val: 0.0380, Test: 0.0365
# Epoch: 069, Loss: 0.0000, Train: 0.0072, Val: 0.0341, Test: 0.0326
# Epoch: 070, Loss: 0.0001, Train: 0.0096, Val: 0.0319, Test: 0.0304
# Epoch: 071, Loss: 0.0001, Train: 0.0095, Val: 0.0317, Test: 0.0302
# Epoch: 072, Loss: 0.0001, Train: 0.0070, Val: 0.0333, Test: 0.0318
# Epoch: 073, Loss: 0.0000, Train: 0.0033, Val: 0.0361, Test: 0.0346
# Epoch: 074, Loss: 0.0000, Train: 0.0030, Val: 0.0392, Test: 0.0377
# Epoch: 075, Loss: 0.0000, Train: 0.0059, Val: 0.0417, Test: 0.0402
# Epoch: 076, Loss: 0.0000, Train: 0.0074, Val: 0.0428, Test: 0.0413
# Epoch: 077, Loss: 0.0001, Train: 0.0070, Val: 0.0423, Test: 0.0408
# Epoch: 078, Loss: 0.0000, Train: 0.0051, Val: 0.0405, Test: 0.0390
# Epoch: 079, Loss: 0.0000, Train: 0.0028, Val: 0.0379, Test: 0.0364
# Epoch: 080, Loss: 0.0000, Train: 0.0034, Val: 0.0354, Test: 0.0339
# Epoch: 081, Loss: 0.0000, Train: 0.0052, Val: 0.0335, Test: 0.0321
# Epoch: 082, Loss: 0.0000, Train: 0.0059, Val: 0.0328, Test: 0.0314
# Epoch: 083, Loss: 0.0000, Train: 0.0052, Val: 0.0333, Test: 0.0319
# Epoch: 084, Loss: 0.0000, Train: 0.0036, Val: 0.0348, Test: 0.0333
# Epoch: 085, Loss: 0.0000, Train: 0.0025, Val: 0.0367, Test: 0.0352
# Epoch: 086, Loss: 0.0000, Train: 0.0034, Val: 0.0384, Test: 0.0369
# Epoch: 087, Loss: 0.0000, Train: 0.0044, Val: 0.0394, Test: 0.0379
# Epoch: 088, Loss: 0.0000, Train: 0.0045, Val: 0.0395, Test: 0.0380
# Epoch: 089, Loss: 0.0000, Train: 0.0036, Val: 0.0387, Test: 0.0372
# Epoch: 090, Loss: 0.0000, Train: 0.0023, Val: 0.0373, Test: 0.0358
# Epoch: 091, Loss: 0.0000, Train: 0.0021, Val: 0.0358, Test: 0.0343
# Epoch: 092, Loss: 0.0000, Train: 0.0030, Val: 0.0346, Test: 0.0332
# Epoch: 093, Loss: 0.0000, Train: 0.0035, Val: 0.0341, Test: 0.0327
# Epoch: 094, Loss: 0.0000, Train: 0.0031, Val: 0.0344, Test: 0.0329
# Epoch: 095, Loss: 0.0000, Train: 0.0022, Val: 0.0352, Test: 0.0337
# Epoch: 096, Loss: 0.0000, Train: 0.0014, Val: 0.0363, Test: 0.0349
# Epoch: 097, Loss: 0.0000, Train: 0.0019, Val: 0.0374, Test: 0.0359
# Epoch: 098, Loss: 0.0000, Train: 0.0025, Val: 0.0380, Test: 0.0365
# Epoch: 099, Loss: 0.0000, Train: 0.0025, Val: 0.0380, Test: 0.0365
# Epoch: 100, Loss: 0.0000, Train: 0.0020, Val: 0.0375, Test: 0.0360
# Epoch: 101, Loss: 0.0000, Train: 0.0012, Val: 0.0367, Test: 0.0352
# Epoch: 102, Loss: 0.0000, Train: 0.0013, Val: 0.0358, Test: 0.0344
# Epoch: 103, Loss: 0.0000, Train: 0.0018, Val: 0.0352, Test: 0.0338
# Epoch: 104, Loss: 0.0000, Train: 0.0020, Val: 0.0350, Test: 0.0336
# Epoch: 105, Loss: 0.0000, Train: 0.0018, Val: 0.0353, Test: 0.0338
# Epoch: 106, Loss: 0.0000, Train: 0.0012, Val: 0.0358, Test: 0.0343
# Epoch: 107, Loss: 0.0000, Train: 0.0010, Val: 0.0365, Test: 0.0350
# Epoch: 108, Loss: 0.0000, Train: 0.0014, Val: 0.0370, Test: 0.0356
# Epoch: 109, Loss: 0.0000, Train: 0.0016, Val: 0.0373, Test: 0.0358
# Epoch: 110, Loss: 0.0000, Train: 0.0015, Val: 0.0372, Test: 0.0357
# Epoch: 111, Loss: 0.0000, Train: 0.0012, Val: 0.0368, Test: 0.0353
# Epoch: 112, Loss: 0.0000, Train: 0.0010, Val: 0.0363, Test: 0.0348
# Epoch: 113, Loss: 0.0000, Train: 0.0012, Val: 0.0358, Test: 0.0343
# Epoch: 114, Loss: 0.0000, Train: 0.0014, Val: 0.0355, Test: 0.0341
# Epoch: 115, Loss: 0.0000, Train: 0.0013, Val: 0.0356, Test: 0.0341
# Epoch: 116, Loss: 0.0000, Train: 0.0011, Val: 0.0358, Test: 0.0343
# Epoch: 117, Loss: 0.0000, Train: 0.0009, Val: 0.0362, Test: 0.0347
# Epoch: 118, Loss: 0.0000, Train: 0.0010, Val: 0.0366, Test: 0.0351
# Epoch: 119, Loss: 0.0000, Train: 0.0011, Val: 0.0368, Test: 0.0353
# Epoch: 120, Loss: 0.0000, Train: 0.0011, Val: 0.0368, Test: 0.0353
# Epoch: 121, Loss: 0.0000, Train: 0.0010, Val: 0.0366, Test: 0.0351
# Epoch: 122, Loss: 0.0000, Train: 0.0008, Val: 0.0363, Test: 0.0348
# Epoch: 123, Loss: 0.0000, Train: 0.0009, Val: 0.0360, Test: 0.0345
# Epoch: 124, Loss: 0.0000, Train: 0.0010, Val: 0.0358, Test: 0.0343
# Epoch: 125, Loss: 0.0000, Train: 0.0010, Val: 0.0358, Test: 0.0343
# Epoch: 126, Loss: 0.0000, Train: 0.0009, Val: 0.0359, Test: 0.0344
# Epoch: 127, Loss: 0.0000, Train: 0.0008, Val: 0.0361, Test: 0.0346
# Epoch: 128, Loss: 0.0000, Train: 0.0008, Val: 0.0364, Test: 0.0349
# Epoch: 129, Loss: 0.0000, Train: 0.0008, Val: 0.0365, Test: 0.0350
# Epoch: 130, Loss: 0.0000, Train: 0.0008, Val: 0.0365, Test: 0.0351
# Epoch: 131, Loss: 0.0000, Train: 0.0008, Val: 0.0364, Test: 0.0350
# Epoch: 132, Loss: 0.0000, Train: 0.0007, Val: 0.0363, Test: 0.0348
# Epoch: 133, Loss: 0.0000, Train: 0.0007, Val: 0.0361, Test: 0.0346
# Epoch: 134, Loss: 0.0000, Train: 0.0007, Val: 0.0359, Test: 0.0345
# Epoch: 135, Loss: 0.0000, Train: 0.0007, Val: 0.0359, Test: 0.0344
# Epoch: 136, Loss: 0.0000, Train: 0.0007, Val: 0.0360, Test: 0.0345
# Epoch: 137, Loss: 0.0000, Train: 0.0007, Val: 0.0361, Test: 0.0347
# Epoch: 138, Loss: 0.0000, Train: 0.0007, Val: 0.0363, Test: 0.0348
# Epoch: 139, Loss: 0.0000, Train: 0.0007, Val: 0.0364, Test: 0.0349
# Epoch: 140, Loss: 0.0000, Train: 0.0007, Val: 0.0364, Test: 0.0349
# Epoch: 141, Loss: 0.0000, Train: 0.0006, Val: 0.0363, Test: 0.0348
# Epoch: 142, Loss: 0.0000, Train: 0.0006, Val: 0.0362, Test: 0.0347
# Epoch: 143, Loss: 0.0000, Train: 0.0006, Val: 0.0361, Test: 0.0346
# Epoch: 144, Loss: 0.0000, Train: 0.0006, Val: 0.0360, Test: 0.0345
# Epoch: 145, Loss: 0.0000, Train: 0.0006, Val: 0.0360, Test: 0.0345
# Epoch: 146, Loss: 0.0000, Train: 0.0006, Val: 0.0361, Test: 0.0346
# Epoch: 147, Loss: 0.0000, Train: 0.0006, Val: 0.0362, Test: 0.0347
# Epoch: 148, Loss: 0.0000, Train: 0.0006, Val: 0.0363, Test: 0.0348
# Epoch: 149, Loss: 0.0000, Train: 0.0006, Val: 0.0363, Test: 0.0348
# Epoch: 150, Loss: 0.0000, Train: 0.0006, Val: 0.0363, Test: 0.0348
# Epoch: 151, Loss: 0.0000, Train: 0.0006, Val: 0.0362, Test: 0.0348
# Epoch: 152, Loss: 0.0000, Train: 0.0006, Val: 0.0362, Test: 0.0347
# Epoch: 153, Loss: 0.0000, Train: 0.0006, Val: 0.0361, Test: 0.0346
# Epoch: 154, Loss: 0.0000, Train: 0.0006, Val: 0.0361, Test: 0.0346
# Epoch: 155, Loss: 0.0000, Train: 0.0005, Val: 0.0361, Test: 0.0346
# Epoch: 156, Loss: 0.0000, Train: 0.0005, Val: 0.0362, Test: 0.0347
# Epoch: 157, Loss: 0.0000, Train: 0.0005, Val: 0.0362, Test: 0.0347
# Epoch: 158, Loss: 0.0000, Train: 0.0005, Val: 0.0363, Test: 0.0348
# Epoch: 159, Loss: 0.0000, Train: 0.0005, Val: 0.0363, Test: 0.0348
# Epoch: 160, Loss: 0.0000, Train: 0.0005, Val: 0.0363, Test: 0.0348
# Epoch: 161, Loss: 0.0000, Train: 0.0005, Val: 0.0362, Test: 0.0347
# Epoch: 162, Loss: 0.0000, Train: 0.0005, Val: 0.0362, Test: 0.0347
# Epoch: 163, Loss: 0.0000, Train: 0.0005, Val: 0.0361, Test: 0.0347
# Epoch: 164, Loss: 0.0000, Train: 0.0005, Val: 0.0361, Test: 0.0347
# Epoch: 165, Loss: 0.0000, Train: 0.0005, Val: 0.0362, Test: 0.0347
# Epoch: 166, Loss: 0.0000, Train: 0.0005, Val: 0.0362, Test: 0.0347
# Epoch: 167, Loss: 0.0000, Train: 0.0005, Val: 0.0362, Test: 0.0347
# Epoch: 168, Loss: 0.0000, Train: 0.0005, Val: 0.0362, Test: 0.0348
# Epoch: 169, Loss: 0.0000, Train: 0.0005, Val: 0.0362, Test: 0.0348
# Epoch: 170, Loss: 0.0000, Train: 0.0005, Val: 0.0362, Test: 0.0347
# Epoch: 171, Loss: 0.0000, Train: 0.0005, Val: 0.0362, Test: 0.0347
# Epoch: 172, Loss: 0.0000, Train: 0.0005, Val: 0.0362, Test: 0.0347
# Epoch: 173, Loss: 0.0000, Train: 0.0005, Val: 0.0362, Test: 0.0347
# Epoch: 174, Loss: 0.0000, Train: 0.0005, Val: 0.0362, Test: 0.0347
# Epoch: 175, Loss: 0.0000, Train: 0.0005, Val: 0.0362, Test: 0.0347
# Epoch: 176, Loss: 0.0000, Train: 0.0005, Val: 0.0362, Test: 0.0347
# Epoch: 177, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 178, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 179, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 180, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 181, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 182, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 183, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 184, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 185, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 186, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 187, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 188, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 189, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 190, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 191, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 192, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 193, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 194, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 195, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 196, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 197, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 198, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 199, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 200, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 201, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 202, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 203, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 204, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 205, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 206, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 207, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 208, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 209, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 210, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 211, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 212, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 213, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 214, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 215, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 216, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 217, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 218, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 219, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 220, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 221, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 222, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 223, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 224, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 225, Loss: 0.0000, Train: 0.0004, Val: 0.0362, Test: 0.0347
# Epoch: 226, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 227, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 228, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 229, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 230, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 231, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 232, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 233, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 234, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 235, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 236, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 237, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 238, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 239, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 240, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 241, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 242, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 243, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 244, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 245, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 246, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 247, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 248, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 249, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 250, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 251, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 252, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 253, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 254, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 255, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 256, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 257, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 258, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 259, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 260, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 261, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 262, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 263, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 264, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 265, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 266, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 267, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 268, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 269, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 270, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 271, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 272, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 273, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 274, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 275, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 276, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 277, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 278, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 279, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 280, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 281, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 282, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 283, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 284, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 285, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 286, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 287, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 288, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 289, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 290, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 291, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 292, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 293, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 294, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 295, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 296, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 297, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 298, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347
# Epoch: 299, Loss: 0.0000, Train: 0.0003, Val: 0.0362, Test: 0.0347

# %%
with open('convert.txt', 'w') as convert_file:
     convert_file.write(json.dumps(results))

# %%
torch.save(model.state_dict(), "model")

# %%
torch.save(data.x_dict, 'x_dict.pt')

# %%
torch.save(data.edge_index_dict,'edge_index_dict.pt')

# %%
torch.save(edge_label_index,'edge_label_index.pt')

# %%
with open('reverse_article_mapping.txt', 'w') as convert_file:
     convert_file.write(json.dumps(reverse_article_mapping))

# %%
with open('reverse_customer_mapping.txt', 'w') as convert_file:
     convert_file.write(json.dumps(reverse_customer_mapping))

# %%
with open('customer_mapping.txt', 'w') as convert_file:
     convert_file.write(json.dumps(customer_mapping))

# %%
torch.save(data.metadata(),'metadata.pt')
